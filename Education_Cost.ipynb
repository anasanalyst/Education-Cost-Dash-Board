# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_rows', 100)  # Set this to however many rows you want to see

# %%
#Reading the CSV
df= pd.read_csv(r"C:\Users\Anus\PycharmProjects\Files\archive (7)\International_Education_Costs.csv")

# %%
df
# Out:
#           Country        City                      University  \
# 0             USA   Cambridge              Harvard University
# 1              UK      London         Imperial College London
# 2          Canada     Toronto           University of Toronto
# 3       Australia   Melbourne         University of Melbourne
# 4         Germany      Munich  Technical University of Munich
# ..            ...         ...                             ...
# 902        France  Strasbourg        University of Strasbourg
# 903      Malaysia       Nilai                            USIM
# 904  Saudi Arabia     Al-Ahsa          King Faisal University
# 905           USA     Seattle        University of Washington
# 906            UK  Nottingham        University of Nottingham
#
#                     Program     Level  Duration_Years  Tuition_USD  \
# 0          Computer Science    Master             2.0        55400
# 1              Data Science    Master             1.0        41200
# ...

# %%
#Using the Head method to see the desired data
df.head(5)
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
#Using the Tail method to see the data from the bottom
df.tail(5)
# Out:
#           Country        City                University               Program  \
# 902        France  Strasbourg  University of Strasbourg        Data Analytics
# 903      Malaysia       Nilai                      USIM      Computer Science
# 904  Saudi Arabia     Al-Ahsa    King Faisal University   Information Systems
# 905           USA     Seattle  University of Washington  Software Development
# 906            UK  Nottingham  University of Nottingham      Data Engineering
#
#         Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 902    Master             2.0         4000               70.2      1000
# 903  Bachelor             3.0         6800               50.5       400
# 904    Master             2.0         4200               64.2       600
# 905       PhD             5.0        50000               77.8      2000
# 906    Master             2.0        34000               61.2       800
#
#      Visa_Fee_USD  Insurance_USD  Exchange_Rate
# ...

# %%
#Using the Dtype method to know the data structure and data types of the columns and it will help us know about the data
df.dtypes
# Out:
# Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
#Using the shape method to see the structure of the dataset
df.shape
# Out:
# (907, 12)

# %%
#Using the info method with which we will get to know about information of the Columns and datatypes again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    object
#  1   City               907 non-null    object
#  2   University         907 non-null    object
#  3   Program            907 non-null    object
#  4   Level              907 non-null    object
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 85.2+ KB

# %%
#Using the Describe method that will give us information of what we can perofrom on the data or the descriptive statistics 
df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# ...

# %%
# Lets check if the data have some duplicates, if yes we will remove them
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 902    False
# 903    False
# 904    False
# 905    False
# 906    False
# Length: 907, dtype: bool

# %%
#Using the the sum method with the duplicated in order to make sure that there are no duplicated mehtods
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Now I'll be checking the Na values
df.isna()
# Out:
#      Country   City  University  Program  Level  Duration_Years  Tuition_USD  \
# 0      False  False       False    False  False           False        False
# 1      False  False       False    False  False           False        False
# 2      False  False       False    False  False           False        False
# 3      False  False       False    False  False           False        False
# 4      False  False       False    False  False           False        False
# ..       ...    ...         ...      ...    ...             ...          ...
# 902    False  False       False    False  False           False        False
# 903    False  False       False    False  False           False        False
# 904    False  False       False    False  False           False        False
# 905    False  False       False    False  False           False        False
# 906    False  False       False    False  False           False        False
#
# ...

# %%
#Using the sum method with Na just like we did in the duplicated method just to make sure there are no NA value
df.isna().sum()
# Out:
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64

# %%
df.dtypes
# Out:
# Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
#The data is in useful form and now we will proceed with the viusalisation of the data using Seaborn and Matplotlib

# %%
#Lets find the Average Fee of students based on top 10 countires without bringing the level of education 
Average_CountryFee=df.groupby("Country")["Tuition_USD"].mean().sort_values(ascending=False).nlargest(10).reset_index()
Average_CountryFee
# Out:
#        Country   Tuition_USD
# 0          USA  47742.307692
# 1    Australia  34610.465116
# 2    Singapore  34172.222222
# 3           UK  30341.935484
# 4       Canada  29456.578947
# 5  New Zealand  29333.333333
# 6          UAE  24687.500000
# 7    Hong Kong  22000.000000
# 8      Ireland  17890.000000
# 9      Lebanon  14200.000000

# %%
#Using Bargrapgh to visualize the data to understand it easily
plt.figure(figsize=(16,6))
plt.style.use("fivethirtyeight")
sns.set_context("paper", font_scale=1.5)
sns.barplot(Average_CountryFee, x="Country", y="Tuition_USD", palette="Set3")
# Out:
# <Axes: xlabel='Country', ylabel='Tuition_USD'>

# %%
# Finding the Cost of living VS the Tuition Fee
df["Cost_Living"]=df["Rent_USD"]* 12 + df['Living_Cost_Index']* 100
df["Cost_Living"].reset_index().head(5)
# Out:
#    index  Cost_Living
# 0      0      34750.0
# 1      1      29180.0
# 2      2      26450.0
# 3      3      23920.0
# 4      4      20250.0

# %%
#Plotting a scatter plot to know the difference between Tuition-Fee and Cost of living
plt.figure(figsize=(16,10))
plt.style.use('bmh')
sns.set_context(font_scale=2)
sns.scatterplot(data=df, x="Tuition_USD", y="Living_Cost_Index", hue="Country",
               palette="tab20", s=100)
plt.title('Tuition Fees vs. Cost of Living by Country')
plt.xlabel('Tuition (USD)')
plt.ylabel('Estimated Annual Living Cost (USD)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
#Visualising the Fee Difference between the different level of education to have a much better understanding 
plt.figure(figsize=(16,8))
plt.style.use('fivethirtyeight')
sns.set_context("paper", font_scale=2)
sns.barplot(data=df, x='Level', y='Tuition_USD', palette="Set2")
plt.title('Tuition Fees Distribution by Degree Level (Log Scale)')
plt.xlabel('Degree Level')

plt.ylabel('Tuition USD')
plt.show()

# %%
#Finding the University with highest tuition fee
Uni_Fee=df.groupby('University')['Tuition_USD'].max().sort_values(ascending=False).nlargest(10).reset_index()
Uni_Fee
# Out:
#                 University  Tuition_USD
# 0      Columbia University        62000
# 1       Harvard University        58000
# 2    University of Chicago        58000
# 3                      MIT        58000
# 4      Stanford University        57000
# 5          Carnegie Mellon        56000
# 6            Massachusetts        56000
# 7          Yale University        54500
# 8  Northeastern University        54000
# 9     Princeton University        54000

# %%
#With the Above finding we will Visualise by using barplot to understand the data
plt.figure(figsize=(14,6))
plt.style.use('bmh')
sns.set_context('paper', font_scale=1.5)
sns.barplot(Uni_Fee, x="University", y="Tuition_USD", palette='rocket')
plt.xticks(rotation=45,ha="right")
plt.xlabel('UNIVERSITIES')
plt.ylabel("Tuition-Fee")
plt.title("TOP 10 EXPENSIVE UNI'S")
plt.tight_layout()
